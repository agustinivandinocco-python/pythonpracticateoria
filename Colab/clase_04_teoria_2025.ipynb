# %% [markdown]
# <a href="https://colab.research.google.com/github/agustinivandinocco-python/pythonpracticateoria/blob/main/Colab/clase_04_teoria_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deudas clases anteriores

# %% [markdown]
# ## builtins

# %% [markdown]
# las funciones built-in son las que llamamos nativas o que ya vienen con el interprete de python

# %% [markdown]
# https://docs.python.org/3/library/functions.html

# %%
import builtins
import keyword

#keyword.kwlist
#dir(builtins)

# %%
lista = keyword.kwlist

num_columns = 4
num_rows = len(lista) // num_columns

for row in range(num_rows):
    for col in range(num_columns):
        print(f"   {lista[row + col * num_rows]:<15}", end='|')
    print('   Fin fila ↵')
# Out:
#    False          |   break          |   finally        |   lambda         |   Fin fila ↵
#    None           |   class          |   for            |   nonlocal       |   Fin fila ↵
#    True           |   continue       |   from           |   not            |   Fin fila ↵
#    and            |   def            |   global         |   or             |   Fin fila ↵
#    as             |   del            |   if             |   pass           |   Fin fila ↵
#    assert         |   elif           |   import         |   raise          |   Fin fila ↵
#    async          |   else           |   in             |   return         |   Fin fila ↵
#    await          |   except         |   is             |   try            |   Fin fila ↵

# %% [markdown]
# # Operadores Lógicos

# %% [markdown]
# Comparadores:
#
#      ==  Es igual a ?
#      !=  Es distinto a?
#      > Mayor que
#      >= Mayor o igual que
#      <  Menor
#      <=  Menor o igual
#
#      in Eata incluido en
#      not in  No esta incluido en

# %% [markdown]
# # Sentencia IF

# %% [markdown]
# Los condicionales son los que definen "ramas" del flujo, véanlas como "bifurcaciones"

# %% [markdown]
# Obviamente la sentencia IF lo que hace es preguntar si se cumple o no una condicion, en caso afirmativo ejecuta la línea que sigue despues de los DOS PUNTOS, caso negativo termina ahí si no hay else, pero si hubiera un else, ejecuta la línea o líneas que siguen despues de os DOS PUNTOS del else

# %% [raw]
# Estrctura del IF
#
# if (condicion):
#     1° linea de codigo
#     2° línea de codigo
#     --------
#     n° linea de codigo
# else:
#     1° linea de codigo
#     2° línea de codigo
#     --------
#     n° linea de codigo

# %% [markdown]
# ## Concepto de la indentación

# %%
num1 = 10
num2 = 30

num1 != num2
# Out:
# True

# %%
accion = "AAPL"
cartera = ["AAPL","AMZN","FB"]

if accion in cartera:
    # que pasa si se cumple la condicion
    print(f"{accion} está en la cartera")

    if num1 > num2:
        print("Num1 es mayor a num2")
    else:
        print("Num1 NO es mayor a num2")

else:
    # No es obligatorio este bloque, pero puedo decir que hacer si no se cumple
    print(F"{accion} NO está en la cartera")

print("Fin")
# Out:
# AAPL está en la cartera
# Num1 NO es mayor a num2
# Fin

# %% [markdown]
# # Concatenados / Anidados

# %% [markdown]
# ## Ejemplo IF concatenado

# %%
# Tarea arregla este script por si el usuario manda cualquier fruta por teclado

resistencias = [7,10,15,20]
precio = float(input("Ingresar el precio: "))

if precio < resistencias[0]:
    print("Resistencia a vencer: ", resistencias[0])

elif precio < resistencias[1]:
    print("Resistencia a vencer: ", resistencias[1])

elif precio < resistencias[2]:
    print("Resistencia a vencer: ", resistencias[2])

elif precio < resistencias[3]:
    print("Resistencia a vencer: ", resistencias[3])

else:
    print("Estamos en máximos históricos")
# Out:
# Ingresar el precio: 14
# Resistencia a vencer:  15

# %% [markdown]
# ### Se puede resolver de una forma mas eficiente?

# %%
# Pensemos juntos como resolveriamos esto si fueran 10, o mas resistencias..
# O si fuera una cantidad a priori desconocida


# Tarea: investigar como se usa el while y hacer esto con un while
precio = float(input("Ingresar el precio: "))
for r in resistencias:
  if precio < r:
    print("Resistencia a vencer: ", r)
    # le tengo que decir que si ya encontro la resistencia que salga de la iteracion
    break
# Out:
# Ingresar el precio: 4
# Resistencia a vencer:  7

# %% [markdown]
# ## Ejemplo IF anidado

# %%
precio = 98

stopLoss = 95
takeProfit = 110


if precio > stopLoss:

    # en ppio mantener
    if precio < takeProfit:
        print("Hold")
    else:
        print("Salida por take Profit")

else:
    print("Salida por Stop Loss")
# Out:
# Hold

# %% [markdown]
# # Diccionarios

# %% [markdown]
# Un diccionario es una estructura Clave=>Valor
# <br>Por ejemplo en lugar de tener un listado de las notas de mis alumnos, podria tener un diccionario con la nota asignada al nombre de cada uno
#
#
# Los diccionarios son colecciones:
#
#     * De elementos asociativos  (es mas estricto que el orden de las listas)
#     * De elementos UNICOS (En sus claves)
#     * Los elementos pueden ser mutables o inmutables (sus valores), pero sobre-escribibles
#     * Los diccionarios son objetos "mutables"

# %% [markdown]
# ## Estructura del diccionario
#
# * Abre con: {
# * Cierra con: }
# * Los elementos se separan con comas
# * Los elementos del diccionario tienen clave y valor
# * La clave se escribe entre comillas preferentemente
# * EL valor se escribe entre comillas solo si es un string
# * Entre clave y valor va un ":"

# %%
panel = {"ALUA":1050 , "BBAR":3590 , "BMA":6770 , "BYMA":[328,330], "CEPU":1125}
type(panel)
# Out:
# dict

# %% [markdown]
# ## Accedo a claves

# %%
# Accedo como las listas, pero mas estrictamente por su clave en lugar de su posicion
panel["ALUA"]
# Out:
# 1050

# %%
# Puedo modificar valores pero no claves

panel["ALUA"] = 1111
panel
# Out:
# {'ALUA': 1111, 'BBAR': 3590, 'BMA': 6770, 'BYMA': [328, 330], 'CEPU': 1125}

# %% [markdown]
# ## Metodo get()

# %%
# Tambien puedo acceder con un metodo para evitar errores

panel.get("AAPL", "No esta en la lista")
# Out:
# 'No esta en la lista'

# %% [markdown]
# ## Agregando mas pares k:v

# %%
# Puedo insertar nuevos pares clave:valor

panel["YPF"] = 43000
panel[1234] = "Cualquiera"
panel["YPF"] = 44000
panel
# Out:
# {'ALUA': 1111,
#  'BBAR': 3590,
#  'BMA': 6770,
#  'BYMA': [328, 330],
#  'CEPU': 1125,
#  'YPF': 44000,
#  1234: 'Cualquiera'}

# %% [markdown]
# ## Operaciones con diccionarios usando metodos
#
# ### Metodo update()

# %%
# Vamos a usar un metodo para actualizar el diccionario previo

panel.update({"NVDA":106, "KO":40})
panel
# Out:
# {'ALUA': 1111,
#  'BBAR': 3590,
#  'BMA': 6770,
#  'BYMA': [328, 330],
#  'CEPU': 1125,
#  'YPF': 44000,
#  1234: 'Cualquiera',
#  'NVDA': 106,
#  'KO': 40}

# %% [markdown]
# ## Operaciones con diccionarios usando logica de conjuntos (recordar sets)

# %%
# Recuerdan que por ejemplo el "|" OR, es una especie de "suma" en terminos de conjuntos?

panel | {"Ticker":123}
# Out:
# {'ALUA': 1111,
#  'BBAR': 3590,
#  'BMA': 6770,
#  'BYMA': [328, 330],
#  'CEPU': 1125,
#  'YPF': 44000,
#  1234: 'Cualquiera',
#  'NVDA': 106,
#  'KO': 40,
#  'Ticker': 123}

# %%
# Puede borrar claves usando pop (igual que en listas pero en lugar de indices me refiero a claves)

# %% [markdown]
# ## Diccionario por comprension

# %%
panel_lista = [ ["ALUA",1050] , ["BBAR",3590] , ["BMA",6770] ]  # esto es una lista d elistas
# Como transformarian ese panel_lista en diccionario?

panel_diccio = {x[0]:x[1] for x in panel_lista}
panel_diccio
# Out:
# {'ALUA': 1050, 'BBAR': 3590, 'BMA': 6770}

# %% [markdown]
# ## Metodos: Keys(), values() e items()

# %% [markdown]
# <br>
# Accedemos por separado a las Claves y Valores

# %%
panel = {"ALUA":1050 , "BBAR":3590 , "BMA":6770 , "BYMA":[328,330], "CEPU":1125}

panel.keys()
# Out:
# dict_keys(['ALUA', 'BBAR', 'BMA', 'BYMA', 'CEPU'])

# %%
panel.values()
# Out:
# dict_values([1050, 3590, 6770, [328, 330], 1125])

# %%
panel.items()
# Out:
# dict_items([('ALUA', 1050), ('BBAR', 3590), ('BMA', 6770), ('BYMA', [328, 330]), ('CEPU', 1125)])

# %% [markdown]
# ¿Que tipo es cada una de estas colecciones?
#
# ¿Como las iterarian?

# %% [markdown]
# ## EJERCICIO

# %%
# Ejercicio

# Como hago para obtener los primeros 3 pares clave valor en formato de panel?
panel = {"ALUA":1050 , "BBAR":3590 , "BMA":6770 , "BYMA":[328,330], "CEPU":1125}


for k,v in panel.items():
  print(f"La clave es {k}")
  print(f"El valor es {v}")
# Out:
# La clave es ALUA
# El valor es 1050
# La clave es BBAR
# El valor es 3590
# La clave es BMA
# El valor es 6770
# La clave es BYMA
# El valor es [328, 330]
# La clave es CEPU
# El valor es 1125

# %%
for k in panel.keys():
  print(f"La clave es {k}")
# Out:
# La clave es ALUA
# La clave es BBAR
# La clave es BMA
# La clave es BYMA
# La clave es CEPU

# %% [markdown]
# ## Distintas formas de Iterar un diccionario

# %% [markdown]
# ### Iterando las tuplas de los items

# %%
# Itero invocando los pares items (desempaqueta tuplas en la iteracion)
diccionario =  {"ALUA":1050 , "BBAR":3590 , "BMA":6770 , "BYMA":[328,330], "CEPU":1125}

for ticker, precio in diccionario.items():
    print(f'la clave es {ticker}, el valor es {precio}')
# Out:
# la clave es ALUA, el valor es 1050
# la clave es BBAR, el valor es 3590
# la clave es BMA, el valor es 6770
# la clave es BYMA, el valor es [328, 330]
# la clave es CEPU, el valor es 1125

# %%
# Itero las tuplas sin desempaquetar

for tupla in diccionario.items():
    print(f'el item es {tupla}')
# Out:
# el item es ('ALUA', 1050)
# el item es ('BBAR', 3590)
# el item es ('BMA', 6770)
# el item es ('BYMA', [328, 330])
# el item es ('CEPU', 1125)

# %% [markdown]
# ### Uso un numerador automatico: enumerate()

# %%
tickers = ["GGAL", "YPF"]

for index, ticker in enumerate(tickers):
  print(f"El ticker: {ticker} nro: {index+1} ")
# Out:
# El ticker: GGAL nro: 1
# El ticker: YPF nro: 2

# %%
for i, tupla in enumerate(diccionario.items()):
    print(f'{i+1}/{len(diccionario)} la clave es {tupla[0]}, el valor es {tupla[1]}')
# Out:
# 1/5 la clave es ALUA, el valor es 1050
# 2/5 la clave es BBAR, el valor es 3590
# 3/5 la clave es BMA, el valor es 6770
# 4/5 la clave es BYMA, el valor es [328, 330]
# 5/5 la clave es CEPU, el valor es 1125

# %% [markdown]
# ### Iterando las claves del diccionario

# %%
# Itero las claves e invoco al diccionario adentro de la iteracion

for k in diccionario.keys():
    print(f'la clave es {k} el valor es {diccionario[k]}')
# Out:
# la clave es ALUA el valor es 1050
# la clave es BBAR el valor es 3590
# la clave es BMA el valor es 6770
# la clave es BYMA el valor es [328, 330]
# la clave es CEPU el valor es 1125

# %% [markdown]
# # La función zip()

# %% [markdown]
# Esto es un "empaquetador" de colecciones, las empareja y devuelve un iterable que se expresa y consume a medida que se va invocando

# %%
tickers = ['ALUA','BBAR','BMA','BYMA']
precios = [1050,  3590,  6770,  328, 1111]
volumenes = [100,  200,  300,  400]

paquete = zip(tickers, precios, volumenes)
paquete

# %%
for a, b, c in paquete:
    print(a, b, c)
# Out:
# ALUA 1050 100
# BBAR 3590 200
# BMA 6770 300
# BYMA 328 400

# %% [markdown]
# Que pasa si vuelvo a iterar?

# %% [markdown]
# ## De zip a Diccionario

# %%
tickers = ['ALUA','BBAR']
cantidades = [1,2]
diccio = dict(zip(tickers, cantidades))
diccio
# Out:
# {'ALUA': 1, 'BBAR': 2}

# %% [markdown]
# ## De zip a Lista

# %%
tickers = ['ALUA','BBAR']
cantidades = [1,2]
lista = list(zip(tickers, cantidades))
lista
# Out:
# [('ALUA', 1), ('BBAR', 2)]

# %% [markdown]
# ## De un diccionario a algo mas copado?

# %% [markdown]
# Supongamos que tenemos los montos de tenencias en cartera de esta fomra:

# %%
tickers = ['TSLA','AMZN','GOOGL','TLT','SHY','BTC']
montos = [12500, 5000, 10500, 20_000, 7*10**2, 7e3]

diccio = dict(zip(tickers, montos))
diccio
# Out:
# {'TSLA': 12500,
#  'AMZN': 5000,
#  'GOOGL': 10500,
#  'TLT': 20000,
#  'SHY': 700,
#  'BTC': 7000.0}

# %% [markdown]
# ¿Si quisiera la suma de montos?

# %%
total = sum(list(diccio.values()))

# %% [markdown]
# Si quisiera los porcentajes? de cada asset en el portafolio?

# %%
[x/total for x in diccio.values()]
# Out:
# [0.2244165170556553,
#  0.08976660682226212,
#  0.18850987432675045,
#  0.3590664272890485,
#  0.012567324955116697,
#  0.12567324955116696]

# %%
import numpy as np

valores = np.array(list(diccio.values()))
valores / total
# Out:
# array([0.22441652, 0.08976661, 0.18850987, 0.35906643, 0.01256732,
#        0.12567325])

# %% [markdown]
# Y si quiero el % de TLT?

# %% [markdown]
# Y si quiero los 3 activos de mayor tenencia?

# %%
# Este ejercicio de encontrar los 3 tickers de mayor valor del diccio sin importar nada esta muy bueno
# Se resuelve con 2 FOR anidados, ejemplo:

  # El FOR externo busca 3 veces el mayor valor de todos
  # El FOR interno recorre todos los elementos del diccio y al finalizar decide cual era el mayor y lo saca


# NOTA: No tiene sentido practico pero si para aprender y ejercitar la mente

# %% [markdown]
# Y si fueran 100, y quiero los tickers del primer decil, o el percentil 6 de mayor tenencia?

# %%
tickers = ['TSLA','AMZN','GOOGL','TLT','SHY','BTC']
montos = [12500, 5000, 10500, 20_000, 7*10**6, 7e3]

diccio = dict(zip(tickers, montos))

maximos = {}
for i in range(3):
  tmax = ""
  vmax = 0
  for ticker, valor in diccio.items():
    if valor > vmax and ticker not in maximos:
      tmax = ticker
      vmax = valor
  maximos[tmax] = vmax

maximos
# Out:
# {'SHY': 7000000, 'TLT': 20000, 'TSLA': 12500}

# %% [markdown]
# # DataFrames

# %%
import pandas as pd
import polars as pl

# %%
tickers = ['TSLA','AMZN','GOOGL','TLT','SHY','BTC']
montos = [12500, 5000, 10500, 20_000, 7*10**2, 7e3]


cartera = pd.DataFrame(data=montos, index=tickers)
cartera.columns=['monto']
cartera
# Out:
#          monto
# TSLA   12500.0
# AMZN    5000.0
# GOOGL  10500.0
# TLT    20000.0
# SHY      700.0
# BTC     7000.0

# %%
cartera['porcentaje'] = cartera.monto / cartera.monto.sum()
cartera
# Out:
#          monto  porcentaje
# TSLA   12500.0    0.224417
# AMZN    5000.0    0.089767
# GOOGL  10500.0    0.188510
# TLT    20000.0    0.359066
# SHY      700.0    0.012567
# BTC     7000.0    0.125673

# %%
# El % de TLT?
cartera.loc['TLT']
# Out:
# monto         20000.000000
# porcentaje        0.359066
# Name: TLT, dtype: float64

# %% [markdown]
# Se acuerdan si quiero los 3 mayores montos?

# %%
cartera.monto
# Out:
# TSLA     12500.0
# AMZN      5000.0
# GOOGL    10500.0
# TLT      20000.0
# SHY        700.0
# BTC       7000.0
# Name: monto, dtype: float64

# %%
cartera.monto.sort_values(ascending=False).head(3)
# Out:
# TLT      20000.0
# TSLA     12500.0
# GOOGL    10500.0
# Name: monto, dtype: float64

# %%
cartera.sort_values("monto", ascending=False).head(3)
# Out:
#          monto  porcentaje
# TLT    20000.0    0.359066
# TSLA   12500.0    0.224417
# GOOGL  10500.0    0.188510

# %%
cartera.sort_values(["monto", "porcentaje"], ascending=[False, True]).head(3)

# %% [markdown]
# # Datos de Mercado

# %%
# pip install yfinance

# %%
import yfinance as yf

# %%
# !pip install curl_cffi -q
# from cachetools import TTLCache
# from curl_cffi import requests as curl_requests

# data_cache = TTLCache(maxsize=100, ttl=60 * 60)
# session = curl_requests.Session(impersonate="chrome")

# def yfd(firms, start="2025-01-01", end=None):
#     tickers = firms if isinstance(firms, (list, tuple)) else [firms]
#     key = (tuple(tickers), start, end)
#     if key in data_cache:
#         return data_cache[key]
#     df = yf.download(tickers=tickers, start=start, end=end, session=session)
#     df.index.name = 'Date'
#     data_cache[key] = df
#     return df

# yfd('GGAL', start='2025-01-01')

# %%
data_aapl = yf.download('AAPL', start='2010-01-01', auto_adjust=True)
data_aapl
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2010-01-04    6.440330    6.455075    6.391277    6.422875  493729600
# 2010-01-05    6.451465    6.487878    6.417459    6.458086  601904800
# 2010-01-06    6.348848    6.477047    6.342228    6.451467  552160000
# 2010-01-07    6.337110    6.379844    6.291067    6.372320  477131200
# 2010-01-08    6.379241    6.379844    6.291369    6.328684  447610800
# ...                ...         ...         ...         ...        ...
# 2025-05-01  213.320007  214.559998  208.899994  209.080002   57365700
# 2025-05-02  205.350006  206.990005  202.160004  206.089996  101010600
# 2025-05-05  198.889999  204.100006  198.210007  203.100006   69018500
# 2025-05-06  198.509995  200.649994  197.020004  198.210007   51216500
# ...

# %% [markdown]
# # Guardado y lectura de excel

# %%
data_aapl.to_excel("data_AAPL.xlsx")

# %%
import pandas as pd

pd.read_excel('data_AAPL.xlsx')
# Out:
#                     Price       Close        High         Low        Open  \
# 0                  Ticker        AAPL        AAPL        AAPL        AAPL
# 1                    Date         NaN         NaN         NaN         NaN
# 2     2010-01-04 00:00:00     6.44033    6.455076    6.391278    6.422876
# 3     2010-01-05 00:00:00    6.451466    6.487879    6.417459    6.458086
# 4     2010-01-06 00:00:00    6.348845    6.477044    6.342224    6.451464
# ...                   ...         ...         ...         ...         ...
# 3856  2025-04-30 00:00:00       212.5  213.580002  206.669998  209.300003
# 3857  2025-05-01 00:00:00  213.320007  214.559998  208.899994  209.080002
# 3858  2025-05-02 00:00:00  205.350006  206.990005  202.160004  206.089996
# 3859  2025-05-05 00:00:00  198.889999  204.100006  198.210007  203.100006
# 3860  2025-05-06 00:00:00  198.509995  200.649994  197.020004  198.210007
#
#          Volume
# 0          AAPL
# 1           NaN
# 2     493729600
# ...

# %%
data_aapl.to_csv('data_AAPL.csv')

# %%
data = yf.download('AAPL', start="2000-01-01", auto_adjust=True)

# Como haria un cruce de medias y una celda booleana con el golden cross?
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2000-01-03    0.842151    0.846382    0.765036    0.789017  535796800
# 2000-01-04    0.771149    0.832276    0.761274    0.814408  512377600
# 2000-01-05    0.782433    0.831805    0.774910    0.780552  778321600
# 2000-01-06    0.714723    0.805004    0.714723    0.798421  767972800
# 2000-01-07    0.748578    0.759864    0.718485    0.726008  460734400
# ...                ...         ...         ...         ...        ...
# 2025-04-30  212.500000  213.580002  206.669998  209.300003   52286500
# 2025-05-01  213.320007  214.559998  208.899994  209.080002   57365700
# 2025-05-02  205.350006  206.990005  202.160004  206.089996  101010600
# 2025-05-05  198.889999  204.100006  198.210007  203.100006   69018500
# ...

# %% [markdown]
# # Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_dir = '/content/drive/My Drive/Clases2025/'

# %%
tickers = ['GGAL','AMZN','TSLA']

for ticker in tickers:
  file_path = f'{file_dir}/data_{ticker}.xlsx'
  data = yf.download(ticker, start="2020-01-01", auto_adjust=True)
  data.to_excel(file_path)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Varios tickers a la vez

# %%
tickers = ['AAPL', 'META', 'AMZN', 'GOOGL', 'NFLX', 'QQQ', 'SQQQ']

data = yf.download(tickers, start='2020-01-01', auto_adjust=True)['Close']
data
# Out:
# [*********************100%***********************]  7 of 7 completed
# Ticker            AAPL        AMZN       GOOGL        META         NFLX  \
# Date
# 2020-01-02   72.716087   94.900497   68.108376  208.795929   329.809998
# 2020-01-03   72.009117   93.748497   67.752075  207.691147   325.899994
# 2020-01-06   72.582901   95.143997   69.557945  211.602722   335.829987
# 2020-01-07   72.241539   95.343002   69.423592  212.060562   330.750000
# 2020-01-08   73.403648   94.598503   69.917725  214.210434   339.260010
# ...                ...         ...         ...         ...          ...
# 2025-05-01  213.320007  190.199997  161.300003  572.210022  1133.469971
# 2025-05-02  205.350006  189.979996  164.029999  597.020020  1156.489990
# 2025-05-05  198.889999  186.350006  164.210007  599.270020  1134.060059
# 2025-05-06  198.509995  185.009995  163.229996  587.309998  1137.689941
# 2025-05-07  196.250000  188.710007  151.380005  596.809998  1155.410034
#
# ...

# %% [markdown]
# ## Magia I: pct_change()

# %%
va = data.pct_change(1)
va
# Out:
# Ticker          AAPL      AMZN     GOOGL      META      NFLX       QQQ  \
# Date
# 2020-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-01-03 -0.009722 -0.012139 -0.005231 -0.005291 -0.011855 -0.009160
# 2020-01-06  0.007968  0.014886  0.026654  0.018834  0.030469  0.006443
# 2020-01-07 -0.004703  0.002092 -0.001932  0.002164 -0.015127 -0.000139
# 2020-01-08  0.016086 -0.007809  0.007118  0.010138  0.025729  0.007516
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-01  0.003859  0.031341  0.015743  0.042277  0.001546  0.013061
# 2025-05-02 -0.037362 -0.001157  0.016925  0.043358  0.020309  0.014844
# 2025-05-05 -0.031459 -0.019107  0.001097  0.003769 -0.019395 -0.005933
# 2025-05-06 -0.001911 -0.007191 -0.005968 -0.019958  0.003201 -0.009302
# 2025-05-07 -0.011385  0.019999 -0.072597  0.016175  0.015576  0.003926
#
# Ticker          SQQQ
# Date
# 2020-01-02       NaN
# 2020-01-03  0.026760
# 2020-01-06 -0.019204
# ...

# %% [markdown]
# ## Magia II: rolling()

# %%
# Vamos a hacer el golden cross

sma50 = data.rolling(50).mean()#.dropna()
sma200 = data.rolling(200).mean()#.dropna()
(sma50 / sma200 - 1)#.dropna()
# Out:
# Ticker          AAPL      AMZN     GOOGL      META      NFLX       QQQ  \
# Date
# 2020-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-01-07       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-01-08       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-01 -0.046404 -0.028941 -0.054244  0.012012  0.156768 -0.030588
# 2025-05-02 -0.049371 -0.032173 -0.056085  0.007705  0.156465 -0.032479
# 2025-05-05 -0.052876 -0.035172 -0.057420  0.003613  0.156234 -0.034149
# 2025-05-06 -0.056645 -0.037986 -0.058887 -0.000128  0.156381 -0.035727
# 2025-05-07 -0.060563 -0.040541 -0.060969 -0.003242  0.157024 -0.037022
#
# Ticker          SQQQ
# Date
# 2020-01-02       NaN
# 2020-01-03       NaN
# 2020-01-06       NaN
# ...

# %%
sma50 > sma200
# Out:
# Ticker       AAPL   AMZN  GOOGL   META   NFLX    QQQ   SQQQ
# Date
# 2020-01-02  False  False  False  False  False  False  False
# 2020-01-03  False  False  False  False  False  False  False
# 2020-01-06  False  False  False  False  False  False  False
# 2020-01-07  False  False  False  False  False  False  False
# 2020-01-08  False  False  False  False  False  False  False
# ...           ...    ...    ...    ...    ...    ...    ...
# 2025-05-01  False  False  False   True   True  False   True
# 2025-05-02  False  False  False   True   True  False   True
# 2025-05-05  False  False  False   True   True  False   True
# 2025-05-06  False  False  False  False   True  False   True
# 2025-05-07  False  False  False  False   True  False   True
#
# [1344 rows x 7 columns]

# %% [markdown]
# ## Repaso covarianza

# %% [markdown]
# $$ \Large  cov_{x,y}  = \sum_{i=1}^{n} \frac{(x_i-\bar{x})(y_i-\bar{y})}{n-1} $$

# %%
data.pct_change().var()
# Out:
# Ticker
# AAPL     0.000427
# AMZN     0.000523
# GOOGL    0.000430
# META     0.000806
# NFLX     0.000814
# QQQ      0.000274
# SQQQ     0.002408
# dtype: float64

# %%
data.pct_change().cov()
# Out:
# Ticker      AAPL      AMZN     GOOGL      META      NFLX       QQQ      SQQQ
# Ticker
# AAPL    0.000427  0.000285  0.000276  0.000333  0.000269  0.000285 -0.000848
# AMZN    0.000285  0.000523  0.000311  0.000408  0.000355  0.000295 -0.000875
# GOOGL   0.000276  0.000311  0.000430  0.000378  0.000264  0.000273 -0.000810
# META    0.000333  0.000408  0.000378  0.000806  0.000405  0.000338 -0.001003
# NFLX    0.000269  0.000355  0.000264  0.000405  0.000814  0.000282 -0.000837
# QQQ     0.000285  0.000295  0.000273  0.000338  0.000282  0.000274 -0.000811
# SQQQ   -0.000848 -0.000875 -0.000810 -0.001003 -0.000837 -0.000811  0.002408

# %% [markdown]
# ## Magia III: matriz de covarianzas, correlacion, etc..

# %% [markdown]
# $$ \Large \rho_{x,y} = \frac{cov_{x,y}}{\sigma_x \sigma_y}  $$

# %%
data.pct_change().corr()
# Out:
# Ticker      AAPL      AMZN     GOOGL      META      NFLX       QQQ      SQQQ
# Ticker
# AAPL    1.000000  0.602779  0.644383  0.568817  0.456341  0.834932 -0.836513
# AMZN    0.602779  1.000000  0.654530  0.628126  0.543474  0.778177 -0.779978
# GOOGL   0.644383  0.654530  1.000000  0.642709  0.445550  0.794484 -0.795776
# META    0.568817  0.628126  0.642709  1.000000  0.500435  0.719541 -0.720448
# NFLX    0.456341  0.543474  0.445550  0.500435  1.000000  0.597920 -0.598178
# QQQ     0.834932  0.778177  0.794484  0.719541  0.597920  1.000000 -0.998816
# SQQQ   -0.836513 -0.779978 -0.795776 -0.720448 -0.598178 -0.998816  1.000000

# %% [markdown]
# ## Magia IV: Estadística descriptiva

# %% [markdown]
# * describe
# * rank
# * quantiles
# * std, kurt, skew

# %%
data.pct_change().describe()
# Out:
# Ticker         AAPL         AMZN        GOOGL         META         NFLX  \
# count   1343.000000  1343.000000  1343.000000  1343.000000  1343.000000
# mean       0.000952     0.000773     0.000810     0.001189     0.001355
# std        0.020654     0.022873     0.020742     0.028383     0.028533
# min       -0.128647    -0.140494    -0.116342    -0.263901    -0.351166
# 25%       -0.008615    -0.011397    -0.009678    -0.011888    -0.011783
# 50%        0.001172     0.000622     0.001422     0.001285     0.001033
# 75%        0.011989     0.012995     0.011546     0.014727     0.014201
# max        0.153289     0.135359     0.102244     0.232824     0.168543
#
# Ticker          QQQ         SQQQ
# count   1343.000000  1343.000000
# mean       0.000760    -0.002029
# std        0.016556     0.049067
# min       -0.119788    -0.352841
# 25%       -0.007167    -0.028326
# 50%        0.001285    -0.003762
# 75%        0.009584     0.021291
# max        0.120031     0.327422

# %%
data.pct_change(252).rank(ascending=False)
# Out:
# Ticker       AAPL   AMZN  GOOGL   META  NFLX    QQQ   SQQQ
# Date
# 2020-01-02    NaN    NaN    NaN    NaN   NaN    NaN    NaN
# 2020-01-03    NaN    NaN    NaN    NaN   NaN    NaN    NaN
# 2020-01-06    NaN    NaN    NaN    NaN   NaN    NaN    NaN
# 2020-01-07    NaN    NaN    NaN    NaN   NaN    NaN    NaN
# 2020-01-08    NaN    NaN    NaN    NaN   NaN    NaN    NaN
# ...           ...    ...    ...    ...   ...    ...    ...
# 2025-05-01  569.0  661.0  843.0  590.0  50.0  734.0  367.0
# 2025-05-02  617.0  597.0  816.0  544.0  30.0  697.0  424.0
# 2025-05-05  677.0  681.0  820.0  567.0  40.0  696.0  428.0
# 2025-05-06  727.0  731.0  832.0  587.0  57.0  713.0  385.0
# 2025-05-07  855.0  721.0  877.0  592.0  65.0  738.0  365.0
#
# [1344 rows x 7 columns]

# %%
data.pct_change(1).rank(pct=True)
# Out:
# Ticker          AAPL      AMZN     GOOGL      META      NFLX       QQQ  \
# Date
# 2020-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-01-03  0.230082  0.241996  0.335071  0.361132  0.247952  0.211467
# 2020-01-06  0.686523  0.781832  0.930752  0.800447  0.906180  0.661206
# 2020-01-07  0.348474  0.534624  0.407297  0.524200  0.210722  0.438570
# 2020-01-08  0.820551  0.317945  0.649293  0.666418  0.871184  0.694713
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-01  0.577811  0.930752  0.818317  0.958302  0.509308  0.832465
# 2025-05-02  0.032018  0.453462  0.834698  0.962770  0.830231  0.853313
# 2025-05-05  0.053611  0.149665  0.492926  0.562174  0.163068  0.276992
# 2025-05-06  0.416977  0.331348  0.322413  0.154133  0.551005  0.209233
# 2025-05-07  0.206255  0.843634  0.005957  0.772897  0.774386  0.593448
#
# Ticker          SQQQ
# Date
# 2020-01-02       NaN
# 2020-01-03  0.784810
# 2020-01-06  0.341772
# ...

# %% [markdown]
# ## Magia V: Conversiones, ej. dataFrame a diccionario

# %%
data.iloc[:5, :3].to_dict()
# Out:
# {'AAPL': {Timestamp('2020-01-02 00:00:00'): 72.7160873413086,
#   Timestamp('2020-01-03 00:00:00'): 72.00911712646484,
#   Timestamp('2020-01-06 00:00:00'): 72.58290100097656,
#   Timestamp('2020-01-07 00:00:00'): 72.24153900146484,
#   Timestamp('2020-01-08 00:00:00'): 73.40364837646484},
#  'AMZN': {Timestamp('2020-01-02 00:00:00'): 94.90049743652344,
#   Timestamp('2020-01-03 00:00:00'): 93.74849700927734,
#   Timestamp('2020-01-06 00:00:00'): 95.14399719238281,
#   Timestamp('2020-01-07 00:00:00'): 95.34300231933594,
#   Timestamp('2020-01-08 00:00:00'): 94.59850311279297},
#  'GOOGL': {Timestamp('2020-01-02 00:00:00'): 68.1083755493164,
#   Timestamp('2020-01-03 00:00:00'): 67.7520751953125,
#   Timestamp('2020-01-06 00:00:00'): 69.55794525146484,
#   Timestamp('2020-01-07 00:00:00'): 69.42359161376953,
#   Timestamp('2020-01-08 00:00:00'): 69.917724609375}}

# %% [markdown]
# ## Magia VI: Graficos rápidos

# %%
data
# Out:
# Ticker            AAPL        AMZN       GOOGL        META         NFLX  \
# Date
# 2020-01-02   72.716087   94.900497   68.108376  208.795929   329.809998
# 2020-01-03   72.009117   93.748497   67.752075  207.691147   325.899994
# 2020-01-06   72.582901   95.143997   69.557945  211.602722   335.829987
# 2020-01-07   72.241539   95.343002   69.423592  212.060562   330.750000
# 2020-01-08   73.403648   94.598503   69.917725  214.210434   339.260010
# ...                ...         ...         ...         ...          ...
# 2025-05-01  213.320007  190.199997  161.300003  572.210022  1133.469971
# 2025-05-02  205.350006  189.979996  164.029999  597.020020  1156.489990
# 2025-05-05  198.889999  186.350006  164.210007  599.270020  1134.060059
# 2025-05-06  198.509995  185.009995  163.229996  587.309998  1137.689941
# 2025-05-07  196.250000  188.710007  151.380005  596.809998  1155.410034
#
# Ticker             QQQ         SQQQ
# Date
# 2020-01-02  209.325912  2329.064453
# ...

# %%
data.divide(data.iloc[0]).mul(100).iloc[:, :3].plot()
# Out:
# <Axes: xlabel='Date'>
